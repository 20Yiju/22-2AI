# %% [markdown]
# HW_7 by 22000690 정이주
#
# 1. Objective : Regression
#
# 2. Input
#
#   * Data file (data_set_train.xlsx)
#
# 3. Output
#
#   * forward pass and loss
#   * Gradient decent
#   * Prediction score
#   * Speend of sound
#   * Price prediction by Linear regression
#   * Quadratic regression
#   * Multiple Linear regression
#   * Ridge & Lasso Regularization

# %% [markdown]
# # 1️⃣ Simple Linear Regression
# ## What is Regression?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x_data = [1.0, 2.0, 3.0]
y_data = [2.0, 4.0, 6.0]

#Our model forward pass
def forward(x):
    return x * w

# Loss function
def loss(y_pred, y):
    return (y_pred - y) * (y_pred - y)

w = 0.00  # initial w
for epoch in range(30):
    for x, y in zip(x_data, y_data):
        y_pred = forward(x)
        l = loss(y_pred, y)
        w = w + 0.05
    print("Epcoh", epoch, "\t(x,y): ", x,y,"\tw=",'%.2f'%w,"\tloss=",'%.2f'%l)
    plt.scatter(w,l, color = 'r')
# Out:
# Epcoh 0 	(x,y):  3.0 6.0 	w= 0.15 	loss= 32.49
# Epcoh 1 	(x,y):  3.0 6.0 	w= 0.30 	loss= 27.56
# Epcoh 2 	(x,y):  3.0 6.0 	w= 0.45 	loss= 23.04
# Epcoh 3 	(x,y):  3.0 6.0 	w= 0.60 	loss= 18.92
# Epcoh 4 	(x,y):  3.0 6.0 	w= 0.75 	loss= 15.21
# Epcoh 5 	(x,y):  3.0 6.0 	w= 0.90 	loss= 11.90
# Epcoh 6 	(x,y):  3.0 6.0 	w= 1.05 	loss= 9.00
# Epcoh 7 	(x,y):  3.0 6.0 	w= 1.20 	loss= 6.50
# Epcoh 8 	(x,y):  3.0 6.0 	w= 1.35 	loss= 4.41
# Epcoh 9 	(x,y):  3.0 6.0 	w= 1.50 	loss= 2.72
# Epcoh 10 	(x,y):  3.0 6.0 	w= 1.65 	loss= 1.44
# Epcoh 11 	(x,y):  3.0 6.0 	w= 1.80 	loss= 0.56
# Epcoh 12 	(x,y):  3.0 6.0 	w= 1.95 	loss= 0.09
# Epcoh 13 	(x,y):  3.0 6.0 	w= 2.10 	loss= 0.02
# Epcoh 14 	(x,y):  3.0 6.0 	w= 2.25 	loss= 0.36
# Epcoh 15 	(x,y):  3.0 6.0 	w= 2.40 	loss= 1.10
# Epcoh 16 	(x,y):  3.0 6.0 	w= 2.55 	loss= 2.25
# Epcoh 17 	(x,y):  3.0 6.0 	w= 2.70 	loss= 3.80
# Epcoh 18 	(x,y):  3.0 6.0 	w= 2.85 	loss= 5.76
# Epcoh 19 	(x,y):  3.0 6.0 	w= 3.00 	loss= 8.12
# Epcoh 20 	(x,y):  3.0 6.0 	w= 3.15 	loss= 10.89
# Epcoh 21 	(x,y):  3.0 6.0 	w= 3.30 	loss= 14.06
# Epcoh 22 	(x,y):  3.0 6.0 	w= 3.45 	loss= 17.64
# Epcoh 23 	(x,y):  3.0 6.0 	w= 3.60 	loss= 21.62
# Epcoh 24 	(x,y):  3.0 6.0 	w= 3.75 	loss= 26.01
# Epcoh 25 	(x,y):  3.0 6.0 	w= 3.90 	loss= 30.80
# Epcoh 26 	(x,y):  3.0 6.0 	w= 4.05 	loss= 36.00
# Epcoh 27 	(x,y):  3.0 6.0 	w= 4.20 	loss= 41.60
# Epcoh 28 	(x,y):  3.0 6.0 	w= 4.35 	loss= 47.61
# Epcoh 29 	(x,y):  3.0 6.0 	w= 4.50 	loss= 54.02

# %%
# Training Data
x_data = [1, 2, 3]
y_data = [2, 4, 6]

# compute gradient
def gradient(x, y):  # d_loss/d_w
    return 2 * x * (x * w -y)

w = 1.00  # initial w
for epoch in range(30):
    for x, y in zip(x_data, y_data):
        y_pred = forward(x)
        l = loss(y_pred, y)
        grad = gradient(x, y)
        w = w - 0.005 * grad
    print("Epcoh", epoch, "\t(x,y): ", x,y,"\tw=",'%.2f'%w,"\tloss=",'%.2f'%l,"\tGrad=",'%.2f'%grad)
    plt.scatter(w,l, color = 'r')
# Out:
# Epcoh 0 	(x,y):  3 6 	w= 1.14 	loss= 8.13 	Grad= -17.11
# Epcoh 1 	(x,y):  3 6 	w= 1.25 	loss= 6.08 	Grad= -14.80
# Epcoh 2 	(x,y):  3 6 	w= 1.35 	loss= 4.55 	Grad= -12.80
# Epcoh 3 	(x,y):  3 6 	w= 1.44 	loss= 3.40 	Grad= -11.07
# Epcoh 4 	(x,y):  3 6 	w= 1.52 	loss= 2.54 	Grad= -9.57
# Epcoh 5 	(x,y):  3 6 	w= 1.58 	loss= 1.90 	Grad= -8.28
# Epcoh 6 	(x,y):  3 6 	w= 1.64 	loss= 1.42 	Grad= -7.16
# Epcoh 7 	(x,y):  3 6 	w= 1.69 	loss= 1.06 	Grad= -6.19
# Epcoh 8 	(x,y):  3 6 	w= 1.73 	loss= 0.80 	Grad= -5.36
# Epcoh 9 	(x,y):  3 6 	w= 1.77 	loss= 0.60 	Grad= -4.63
# Epcoh 10 	(x,y):  3 6 	w= 1.80 	loss= 0.45 	Grad= -4.01
# Epcoh 11 	(x,y):  3 6 	w= 1.82 	loss= 0.33 	Grad= -3.46
# Epcoh 12 	(x,y):  3 6 	w= 1.85 	loss= 0.25 	Grad= -3.00
# Epcoh 13 	(x,y):  3 6 	w= 1.87 	loss= 0.19 	Grad= -2.59
# Epcoh 14 	(x,y):  3 6 	w= 1.89 	loss= 0.14 	Grad= -2.24
# Epcoh 15 	(x,y):  3 6 	w= 1.90 	loss= 0.10 	Grad= -1.94
# Epcoh 16 	(x,y):  3 6 	w= 1.92 	loss= 0.08 	Grad= -1.68
# Epcoh 17 	(x,y):  3 6 	w= 1.93 	loss= 0.06 	Grad= -1.45
# Epcoh 18 	(x,y):  3 6 	w= 1.94 	loss= 0.04 	Grad= -1.25
# Epcoh 19 	(x,y):  3 6 	w= 1.95 	loss= 0.03 	Grad= -1.08
# Epcoh 20 	(x,y):  3 6 	w= 1.95 	loss= 0.02 	Grad= -0.94
# Epcoh 21 	(x,y):  3 6 	w= 1.96 	loss= 0.02 	Grad= -0.81
# Epcoh 22 	(x,y):  3 6 	w= 1.96 	loss= 0.01 	Grad= -0.70
# Epcoh 23 	(x,y):  3 6 	w= 1.97 	loss= 0.01 	Grad= -0.61
# Epcoh 24 	(x,y):  3 6 	w= 1.97 	loss= 0.01 	Grad= -0.52
# Epcoh 25 	(x,y):  3 6 	w= 1.98 	loss= 0.01 	Grad= -0.45
# Epcoh 26 	(x,y):  3 6 	w= 1.98 	loss= 0.00 	Grad= -0.39
# Epcoh 27 	(x,y):  3 6 	w= 1.98 	loss= 0.00 	Grad= -0.34
# Epcoh 28 	(x,y):  3 6 	w= 1.99 	loss= 0.00 	Grad= -0.29
# Epcoh 29 	(x,y):  3 6 	w= 1.99 	loss= 0.00 	Grad= -0.25

# %%
# After training
print("Predicted score (after training)",  "When x=4, y will be : ", forward(4))
print("Predicted score (after training)",  "When x=4, y will be : ", forward(6))
# Out:
# Predicted score (after training) When x=4, y will be :  7.94865542184356
# Predicted score (after training) When x=4, y will be :  11.922983132765339

# %% [markdown]
# # Exercise1: speed of sound

# %%
x_data = [0.0, 1.0, 2.0, 3.0]
y_data = [331.0, 331.6, 332.2, 332.8]
w=0.0
b=0.0

epochs = 1000
learning_rate = 0.03
for i in range(epochs):
    for x, y in zip(x_data,y_data):
        y_pred = x * w + b
        loss = ((y_pred - y) ** 2) #MSE
        grad_w = ((w * x + b - y) * 2 * x)
        grad_b = ((w * x + b - y) * 2)
        w -= learning_rate * grad_w
        b -= learning_rate * grad_b

# %%
# prediction of speend at temperature of 20degree
x_new = 20
y_pred = x_new * w + b
print(y_pred)
# Out:
# 343.000000000003

# %% [markdown]
# # 1️⃣ Linear Regression Using Real Estate Data
# ## sklearn Regression

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
#read the data file
df = pd.read_excel('data_set_train.xlsx')
df.head()
# Out:
#   aptnm(아파트 이름) yyyyqrt(거래년도 분기별)  price(가격)  con_year(건축년도) dong(동)  \
# 0      강남역우정에쉐르            2006Q1       9000            2004     역삼동
# 1      강남역우정에쉐르            2006Q1       9000            2004     역삼동
# 2       개포주공1단지            2006Q1      73000            1982     개포동
# 3       개포주공1단지            2006Q1      70000            1982     개포동
# 4       개포주공1단지            2006Q1      40000            1982     개포동
#
#    area(면적)  floor(층수)  Latitude(위도)  Longtitude(경도)     gdp  ...  \
# 0     17.23          7     37.494204      127.043545  225613  ...
# 1     17.23          7     37.494204      127.043545  225613  ...
# 2     50.38          3     37.478407      127.061375  225613  ...
# 3     50.64          5     37.484609      127.067275  225613  ...
# 4     35.44          4     37.482445      127.051278  225613  ...
#
#    dis_subway(지하철역과의 거리)  brand_r(유명 아파트 브랜드순)  n_home(세대수)  n_dong(동수)  \
# 0             849.353653                     0           52           1
# 1             849.353653                     0           52           1
# 2            1486.178329                     0         5040         124
# 3            1160.598717                     0         5040         124
# 4             650.325555                     0         5040         124
#
#    parking_per(세대별 주차장수)  Heater(난방 시스템)  Yongpae(용적률)  Gunpae(건폐율)  \
# 0                   0.75            개별난방         536.0         58.0
# 1                   0.75            개별난방         536.0         58.0
# 2                   0.49            개별난방          72.0         15.0
# 3                   0.49            개별난방          72.0         15.0
# 4                   0.49            개별난방          72.0         15.0
#
#    Highest(최고층)  Lowest(최저층)
# 0            13           12
# 1            13           12
# 2             5            5
# 3             5            5
# 4             5            5
#
# [5 rows x 29 columns]

# %%
df.corr().head()
# Out:
#                 price(가격)  con_year(건축년도)  area(면적)  floor(층수)  Latitude(위도)  \
# price(가격)        1.000000        0.085364  0.711187   0.094599      0.105059
# con_year(건축년도)   0.085364        1.000000  0.439237   0.390900      0.528441
# area(면적)         0.711187        0.439237  1.000000   0.185766      0.434611
# floor(층수)        0.094599        0.390900  0.185766   1.000000      0.162481
# Latitude(위도)     0.105059        0.528441  0.434611   0.162481      1.000000
#
#                 Longtitude(경도)       gdp  e_grwth(경제성장률)  Seoul_l.rate(지가상승률)  \
# price(가격)            -0.079797  0.289566       -0.132575            -0.044081
# con_year(건축년도)       -0.428207  0.017524        0.018824             0.003777
# area(면적)             -0.238154  0.112332       -0.063985            -0.049426
# floor(층수)            -0.162969 -0.005394       -0.014200            -0.032827
# Latitude(위도)         -0.439299  0.025258       -0.002774            -0.006517
#
#                 house_rate(담보대출금리)  ...  dis_hospital(종합 병원과의 거리)  \
# price(가격)                -0.016064  ...                 -0.027211
# con_year(건축년도)            0.064364  ...                 -0.567171
# area(면적)                  0.073215  ...                 -0.351692
# floor(층수)                 0.096666  ...                 -0.334654
# Latitude(위도)              0.039514  ...                 -0.552484
#
#                 dis_museum(국립 박물관과의 거리)  dis_subway(지하철역과의 거리)  \
# price(가격)                     -0.023917               0.032413
# con_year(건축년도)                 0.192700              -0.375835
# area(면적)                       0.039753              -0.231797
# floor(층수)                      0.119266              -0.262416
# Latitude(위도)                   0.034464              -0.446530
#
#                 brand_r(유명 아파트 브랜드순)  n_home(세대수)  n_dong(동수)  Yongpae(용적률)  \
# price(가격)                   0.148241     0.117208    0.077838     -0.183188
# con_year(건축년도)              0.427227    -0.727402   -0.613206      0.532663
# area(면적)                    0.146997    -0.350279   -0.382750      0.104369
# floor(층수)                   0.206511    -0.356595   -0.414505      0.465783
# Latitude(위도)                0.129443    -0.429316   -0.454962      0.350463
#
#                 Gunpae(건폐율)  Highest(최고층)  Lowest(최저층)
# price(가격)         -0.270909      0.189604     0.099194
# con_year(건축년도)     0.441489      0.608765     0.382408
# area(면적)           0.106880      0.346106     0.222335
# floor(층수)          0.140489      0.621011     0.563960
# Latitude(위도)       0.427392      0.276134     0.195107
#
# [5 rows x 24 columns]

# %%
# the 2017Q1 data
df_2017q1=df[df['yyyyqrt(거래년도 분기별)']=='2017Q1']
df_2017q1.corr().head(5)
# Out:
#                 price(가격)  con_year(건축년도)  area(면적)  floor(층수)  Latitude(위도)  \
# price(가격)        1.000000        0.195676  0.750915   0.135630      0.257352
# con_year(건축년도)   0.195676        1.000000  0.523815   0.397941      0.489696
# area(면적)         0.750915        0.523815  1.000000   0.248797      0.545653
# floor(층수)        0.135630        0.397941  0.248797   1.000000      0.167945
# Latitude(위도)     0.257352        0.489696  0.545653   0.167945      1.000000
#
#                 Longtitude(경도)  gdp  e_grwth(경제성장률)  Seoul_l.rate(지가상승률)  \
# price(가격)             0.010404  NaN             NaN                  NaN
# con_year(건축년도)       -0.430093  NaN             NaN                  NaN
# area(면적)             -0.212950  NaN             NaN                  NaN
# floor(층수)            -0.156736  NaN             NaN                  NaN
# Latitude(위도)         -0.431871  NaN             NaN                  NaN
#
#                 house_rate(담보대출금리)  ...  dis_hospital(종합 병원과의 거리)  \
# price(가격)                      NaN  ...                 -0.145817
# con_year(건축년도)                 NaN  ...                 -0.496689
# area(면적)                       NaN  ...                 -0.455760
# floor(층수)                      NaN  ...                 -0.428012
# Latitude(위도)                   NaN  ...                 -0.578459
#
#                 dis_museum(국립 박물관과의 거리)  dis_subway(지하철역과의 거리)  \
# price(가격)                      0.105243              -0.110320
# con_year(건축년도)                 0.218183              -0.313006
# area(면적)                       0.193330              -0.344588
# floor(층수)                      0.184909              -0.312841
# Latitude(위도)                   0.111685              -0.503209
#
#                 brand_r(유명 아파트 브랜드순)  n_home(세대수)  n_dong(동수)  Yongpae(용적률)  \
# price(가격)                   0.029404    -0.052200   -0.062324     -0.041887
# con_year(건축년도)              0.464157    -0.770045   -0.606255      0.538642
# area(면적)                    0.127014    -0.500390   -0.524550      0.291799
# floor(층수)                   0.228352    -0.353591   -0.459423      0.458863
# Latitude(위도)                0.095807    -0.484441   -0.531009      0.401415
#
#                 Gunpae(건폐율)  Highest(최고층)  Lowest(최저층)
# price(가격)         -0.080448      0.221051     0.259664
# con_year(건축년도)     0.418533      0.646392     0.387804
# area(면적)           0.267682      0.462117     0.394585
# floor(층수)          0.092783      0.622454     0.616155
# Latitude(위도)       0.483072      0.323761     0.271874
#
# [5 rows x 24 columns]

# %%
# Area vs. Price
plt.figure(figsize=(12,5))
plt.scatter(df_2017q1['area(면적)'], df_2017q1['price(가격)'], alpha=0.1)
plt.xlabel('area')
plt.ylabel('price')
plt.show()

# %%
from sklearn.model_selection import train_test_split

X = np.array(df_2017q1['area(면적)']).reshape(-1, 1) # area
y = np.array(df_2017q1['price(가격)']).reshape(-1, 1) #price

train_x, test_x, train_y, test_y = train_test_split(X, y, test_size = 0.10, random_state = 2)

print("train_x shape  = ",train_x.shape, "train_y shape  = ", train_y.shape)
print("test_x shape  = ",test_x.shape, "test_y shape  = ", test_y.shape)
# Out:
# train_x shape  =  (702, 1) train_y shape  =  (702, 1)
# test_x shape  =  (78, 1) test_y shape  =  (78, 1)

# %%
# Training

simple_lin_reg = LinearRegression(normalize = True)
simple_lin_reg.fit(train_x, train_y)

print("Fitting results: ", 'w = ', simple_lin_reg.intercept_, 'b = ', simple_lin_reg.coef_ )

# Prediction

test_y_pred=simple_lin_reg.predict(test_x)

print("Testing results: ", 'score = ', simple_lin_reg.score(test_x, test_y))

# Visulization
plt.figure(figsize=(10, 4))
plt.subplot(1,2,1)
plt.scatter(train_x,train_y,color='k')
plt.scatter(train_x,simple_lin_reg.predict(train_x),color='c')
plt.title('Trainig data'); plt.xlim(0,260); plt.ylim(0,550000);

plt.subplot(1,2,2)
plt.scatter(test_x, test_y, color ='k')
plt.scatter(test_x, test_y_pred,color='r')
plt.title('Testing data'); plt.xlim(0,260); plt.ylim(0,550000);
# Out:
# Fitting results:  w =  [35857.48945078] b =  [[991.57606614]]
# Testing results:  score =  0.5938353309667361
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(

# %% [markdown]
# # Regression by Quadratic function

# %%
# Generating X^2
train_x_s = np.c_[train_x, train_x**2]
test_x_s = np.c_[test_x, test_x**2]

train_x_s
# Out:
# array([[5.65700000e+01, 3.20016490e+03],
#        [1.71940000e+02, 2.95633636e+04],
#        [1.61470000e+02, 2.60725609e+04],
#        ...,
#        [8.48600000e+01, 7.20121960e+03],
#        [2.44320000e+02, 5.96922624e+04],
#        [4.25500000e+01, 1.81050250e+03]])

# %%
# Training

lin_reg_poly = LinearRegression(normalize = True)
lin_reg_poly.fit(train_x_s, train_y)

print("Fitting results: ", 'b = ', lin_reg_poly.intercept_, 'w = ', lin_reg_poly.coef_)

# Prediction

test_y_pred_poly = lin_reg_poly.predict(test_x_s)

print("Testing results: ", 'score = ', lin_reg_poly.score(test_x_s, test_y))

# Visualization
plt.figure(figsize=(10, 4))
plt.subplot(1,2,1)
plt.scatter(test_x, test_y, color ='k')
plt.scatter(test_x, test_y_pred,color='r')
plt.title('Testing data - Linear'); plt.xlim(0,260); plt.ylim(0,550000);

plt.subplot(1,2,2)
plt.scatter(test_x[:,0], test_y, color ='k')
plt.scatter(test_x[:,0], test_y_pred_poly, color ='b')
plt.title('Testing data - Polynomial'); plt.xlim(0,260); plt.ylim(0,550000);
# Out:
# Fitting results:  b =  [94791.84193193] w =  [[-431.72413584    6.73213135]]
# Testing results:  score =  0.6961349781442754
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(

# %% [markdown]
# ## Multiple Regression

# %%
# for 2017q1
df_2017q1=df[df['yyyyqrt(거래년도 분기별)']=='2017Q1']

# %%
df_2017q1
# Out:
#       aptnm(아파트 이름) yyyyqrt(거래년도 분기별)  price(가격)  con_year(건축년도) dong(동)  \
# 15731         SM드림빌            2017Q1      50000            2003     삼성동
# 15732         SM드림빌            2017Q1      48500            2003     삼성동
# 15733         SM드림빌            2017Q1      50000            2003     삼성동
# 15734         SM드림빌            2017Q1      48500            2003     삼성동
# 15735            가람            2017Q1      90000            1993     일원동
# ...             ...               ...        ...             ...     ...
# 16506          현대한강            2017Q1     138000            1992     청담동
# 16507          현대한강            2017Q1     140000            1992     청담동
# 16508          현대한강            2017Q1     140000            1992     청담동
# 16509          현대한강            2017Q1     140000            1992     청담동
# 16510          현대한강            2017Q1     140000            1992     청담동
#
#        area(면적)  floor(층수)  Latitude(위도)  Longtitude(경도)     gdp  ...  \
# 15731     52.79          3     37.506167      127.050942  406309  ...
# 15732     51.75          3     37.513991      127.049897  406309  ...
# 15733     52.79          3     37.506167      127.050942  406309  ...
# 15734     51.75          3     37.513991      127.049897  406309  ...
# 15735     75.16          5     37.492741      127.090884  406309  ...
# ...         ...        ...           ...             ...     ...  ...
# 16506    136.26          3     37.526437      127.049673  406309  ...
# 16507    136.26          4     37.522441      127.050580  406309  ...
# 16508    136.26          4     37.522441      127.050580  406309  ...
# 16509    136.26          4     37.522441      127.050580  406309  ...
# 16510    136.26          4     37.522441      127.050580  406309  ...
#
#        dis_subway(지하철역과의 거리)  brand_r(유명 아파트 브랜드순)  n_home(세대수)  n_dong(동수)  \
# 15731             255.707173                     0           16           1
# 15732             604.345130                     0           16           1
# 15733             255.707173                     0           16           1
# 15734             604.345130                     0           16           1
# 15735            1012.119982                     0          496          13
# ...                      ...                   ...          ...         ...
# 16506             838.410487                     0           18           1
# 16507             389.152036                     0           18           1
# 16508             389.152036                     0           18           1
# 16509             389.152036                     0           18           1
# 16510             389.152036                     0           18           1
#
#        parking_per(세대별 주차장수)  Heater(난방 시스템)  Yongpae(용적률)  Gunpae(건폐율)  \
# 15731                   0.75            개별난방         241.0         59.0
# 15732                   0.75            개별난방         241.0         59.0
# 15733                   0.75            개별난방         241.0         59.0
# 15734                   0.75            개별난방         241.0         59.0
# 15735                      1            지역난방         109.0         27.0
# ...                      ...             ...           ...          ...
# 16506                      -            개별난방         290.0          NaN
# 16507                      -            개별난방         290.0          NaN
# 16508                      -            개별난방         290.0          NaN
# 16509                      -            개별난방         290.0          NaN
# 16510                      -            개별난방         290.0          NaN
#
#        Highest(최고층)  Lowest(최저층)
# 15731             5            3
# 15732             5            3
# 15733             5            3
# 15734             5            3
# 15735             5            4
# ...             ...          ...
# 16506            10           10
# 16507            10           10
# 16508            10           10
# 16509            10           10
# 16510            10           10
#
# [780 rows x 29 columns]

# %%
df_2017q1_mf=df_2017q1.copy()
col=df_2017q1.columns
for c in col:
    if(df_2017q1_mf[c].dtypes == 'object'):
        df_2017q1_mf=df_2017q1_mf.drop(c,axis=1)
        continue
    if(all(round(df_2017q1_mf[c].mean(),6)==round(df_2017q1_mf[c],6) )):
        df_2017q1_mf=df_2017q1_mf.drop(c,axis=1)
df_2017q1_mf['Yongpae(용적률)']=df_2017q1_mf['Yongpae(용적률)'].replace(np.nan,df_2017q1_mf['Yongpae(용적률)'].mean())
df_2017q1_mf['Gunpae(건폐율)']=df_2017q1_mf['Gunpae(건폐율)'].replace(np.nan,df_2017q1_mf['Gunpae(건폐율)'].mean())
df_2017q1_mf
# Out:
#        price(가격)  con_year(건축년도)  area(면적)  floor(층수)  Latitude(위도)  \
# 15731      50000            2003     52.79          3     37.506167
# 15732      48500            2003     51.75          3     37.513991
# 15733      50000            2003     52.79          3     37.506167
# 15734      48500            2003     51.75          3     37.513991
# 15735      90000            1993     75.16          5     37.492741
# ...          ...             ...       ...        ...           ...
# 16506     138000            1992    136.26          3     37.526437
# 16507     140000            1992    136.26          4     37.522441
# 16508     140000            1992    136.26          4     37.522441
# 16509     140000            1992    136.26          4     37.522441
# 16510     140000            1992    136.26          4     37.522441
#
#        Longtitude(경도)  dis_park(국립 공원과의 거리)  dis_highschool(고등학교와의 거리)  \
# 15731      127.050942            950.391401                 491.265016
# 15732      127.049897            494.502095                 624.555650
# 15733      127.050942            950.391401                 491.265016
# 15734      127.049897            494.502095                 624.555650
# 15735      127.090884            535.258347                 535.376070
# ...               ...                   ...                        ...
# 16506      127.049673            619.653317                 568.517302
# 16507      127.050580            206.757999                 681.328245
# 16508      127.050580            206.757999                 681.328245
# 16509      127.050580            206.757999                 681.328245
# 16510      127.050580            206.757999                 681.328245
#
#        dis_reconst(재개발 지역과의 거리)  dis_univ(대학과의 거리)  dis_hospital(종합 병원과의 거리)  \
# 15731                878.562497        2124.821260               1066.116490
# 15732               1088.810542        1694.016155                569.707611
# 15733                878.562497        2124.821260               1066.116490
# 15734               1088.810542        1694.016155                569.707611
# 15735               1312.172883        4647.218036                442.237568
# ...                         ...                ...                       ...
# 16506               1137.362503        1953.267584                816.303318
# 16507                846.613912        1828.076442                380.837660
# 16508                846.613912        1828.076442                380.837660
# 16509                846.613912        1828.076442                380.837660
# 16510                846.613912        1828.076442                380.837660
#
#        dis_museum(국립 박물관과의 거리)  dis_subway(지하철역과의 거리)  brand_r(유명 아파트 브랜드순)  \
# 15731               456.171804             255.707173                     0
# 15732               858.105695             604.345130                     0
# 15733               456.171804             255.707173                     0
# 15734               858.105695             604.345130                     0
# 15735              1057.181210            1012.119982                     0
# ...                        ...                    ...                   ...
# 16506              1290.033821             838.410487                     0
# 16507              1336.459786             389.152036                     0
# 16508              1336.459786             389.152036                     0
# 16509              1336.459786             389.152036                     0
# 16510              1336.459786             389.152036                     0
#
#        n_home(세대수)  n_dong(동수)  Yongpae(용적률)  Gunpae(건폐율)  Highest(최고층)  \
# 15731           16           1         241.0    59.000000             5
# 15732           16           1         241.0    59.000000             5
# 15733           16           1         241.0    59.000000             5
# 15734           16           1         241.0    59.000000             5
# 15735          496          13         109.0    27.000000             5
# ...            ...         ...           ...          ...           ...
# 16506           18           1         290.0    23.074176            10
# 16507           18           1         290.0    23.074176            10
# 16508           18           1         290.0    23.074176            10
# 16509           18           1         290.0    23.074176            10
# 16510           18           1         290.0    23.074176            10
#
#        Lowest(최저층)
# 15731            3
# 15732            3
# 15733            3
# 15734            3
# 15735            4
# ...            ...
# 16506           10
# 16507           10
# 16508           10
# 16509           10
# 16510           10
#
# [780 rows x 20 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(df_2017q1_mf.iloc[:,1:],df_2017q1_mf.iloc[:,0],test_size=0.10, random_state=2)

#split the data file into train and test

print("X_train.shape =", X_train.shape)
print("y_train.shape =", y_train.shape)

print("X_test.shape =", X_test.shape)
print("y_test.shape =", y_test.shape)
# Out:
# X_train.shape = (702, 19)
# y_train.shape = (702,)
# X_test.shape = (78, 19)
# y_test.shape = (78,)

# %%
# create object 
mul_reg = LinearRegression(normalize=True)

# train
mul_reg.fit(X_train, y_train)


# check coefficients and intercept
print("coef_:", mul_reg.coef_)             # w
print("intercept_:", mul_reg.intercept_)   # b
# Out:
# coef_: [ 1.82057172e+02  1.24331853e+03  7.46420414e+02  7.03658562e+05
#  -5.93845750e+05 -4.49583975e+00  3.83181929e+00 -7.31375238e+00
#   1.49634861e+01  1.13172730e+01  2.62270050e+00 -6.01879150e+00
#   1.05155808e+03  7.64355121e-01  5.28651512e+02 -7.80285592e+01
#   2.50487278e+02 -5.70073837e+02  3.61334244e+03]
# intercept_: 48621863.3230263
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(

# %%
# evaluation
print("Training set score: {:.2f}".format(mul_reg.score(X_train, y_train)))
print("Test set score: {:.2f}".format(mul_reg.score(X_test, y_test)))
# Out:
# Training set score: 0.80
# Test set score: 0.78

# %% [markdown]
# ## Lasso ($L_1$ regularization)

# %%
from sklearn.linear_model import Lasso

#lasso alpha = 1
lasso = Lasso(alpha = 1, normalize=True).fit(X_train, y_train)    
    
#split the data file into train and test
print("X_train.shape =", X_train.shape)
print("y_train.shape =", y_train.shape)
print("X_test.shape =", X_test.shape)
print("y_test.shape =", y_test.shape)
# Out:
# X_train.shape = (702, 19)
# y_train.shape = (702,)
# X_test.shape = (78, 19)
# y_test.shape = (78,)
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(

# %%
#lasso alpha = 0.01
lasso001 = Lasso(0.01, normalize = True).fit(X_train, y_train)

#print lasso appha = 1
print("Training score: {:.2f}".format(lasso.score(X_train, y_train)))
print("Test score: {:.2f}".format(lasso.score(X_test, y_test)))
print("Number of features used:", np.sum(lasso.coef_ != 0))
# Out:
# Training score: 0.80
# Test score: 0.78
# Number of features used: 19
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(

# %%
#lasso alpha = 0.01
lasso001 = Lasso(0.01, normalize = True).fit(X_train, y_train)

#print lasso appha = 0.01
print("Training score: {:.2f}".format(lasso001.score(X_train, y_train)))
print("Test score: {:.2f}".format(lasso001.score(X_test, y_test)))
print("Number of features used:", np.sum(lasso001.coef_ != 0))
# Out:
# Training score: 0.77
# Test score: 0.76
# Number of features used: 23
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(

# %% [markdown]
# ## Ridge ($L_2$ regularization)

# %%
from sklearn.linear_model import Ridge

# %%
ridge = Ridge(alpha=0.01, normalize=True).fit(X_train, y_train)

print("ridge.coef_: {}".format(ridge.coef_))             # w
print("ridge.intercept_: {}".format(ridge.intercept_))   # b
# Out:
# ridge.coef_: [ 2.27963972e+02  1.22410965e+03  7.33687460e+02  6.51211759e+05
#  -3.76429656e+05 -3.60610453e+00  2.61484319e+00 -8.45447188e+00
#   1.19727788e+01  1.16414288e+01  2.90330002e+00 -4.54672254e+00
#   9.78316980e+02  1.51797276e+00  4.80065907e+02 -7.06718315e+01
#   1.76176512e+02 -5.37562548e+02  3.33249729e+03]
# ridge.intercept_: 22885508.775179677
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(

# %%
print("Training score: {:.2f}".format(ridge.score(X_train, y_train)))
print("Test score: {:.2f}".format(ridge.score(X_test, y_test)))
# Out:
# Training score: 0.80
# Test score: 0.78

# %% [markdown]
# # Multiple regression with whole data - not included in ppt

# %%
#   multiple regression for whole data

df_multi=df.copy()
col=df.columns
for c in col:
    #print(df[c].dtypes)
    if(df_multi[c].dtypes == 'object'):
        df_multi=df_multi.drop(c,axis=1)
        continue
#columns=df_multi.columns
#for c in columns:
    #print(df_2017q1_1f[c].dtypes)
df_multi['Yongpae(용적률)']=df_multi['Yongpae(용적률)'].replace(np.nan,df_multi['Yongpae(용적률)'].mean())
df_multi['Gunpae(건폐율)']=df_multi['Gunpae(건폐율)'].replace(np.nan,df_multi['Gunpae(건폐율)'].mean())
df_multi
# Out:
#        price(가격)  con_year(건축년도)  area(면적)  floor(층수)  Latitude(위도)  \
# 0           9000            2004     17.23          7     37.494204
# 1           9000            2004     17.23          7     37.494204
# 2          73000            1982     50.38          3     37.478407
# 3          70000            1982     50.64          5     37.484609
# 4          40000            1982     35.44          4     37.482445
# ...          ...             ...       ...        ...           ...
# 17395     179000            1998    169.63          8     37.526956
# 17396     122500            1999    244.14          4     37.496260
# 17397      64000            2004     96.21          1     37.491379
# 17398     170000            1992    136.26          8     37.524675
# 17399     170000            1992    136.26          8     37.524675
#
#        Longtitude(경도)     gdp  e_grwth(경제성장률)  Seoul_l.rate(지가상승률)  \
# 0          127.043545  225613             6.3             0.152881
# 1          127.043545  225613             6.3             0.152881
# 2          127.061375  225613             6.3             0.152881
# 3          127.067275  225613             6.3             0.152881
# 4          127.051278  225613             6.3             0.152881
# ...               ...     ...             ...                  ...
# 17395      127.053126  446835             3.8             0.069818
# 17396      127.046404  446835             3.8             0.069818
# 17397      127.034880  446835             3.8             0.069818
# 17398      127.056226  446835             3.8             0.069818
# 17399      127.056226  446835             3.8             0.069818
#
#        house_rate(담보대출금리)  ...  dis_hospital(종합 병원과의 거리)  \
# 0                5.559495  ...                291.146810
# 1                5.559495  ...                291.146810
# 2                5.559495  ...               2081.070695
# 3                5.559495  ...               1733.995826
# 4                5.559495  ...               1231.289066
# ...                   ...  ...                       ...
# 17395            5.883320  ...                926.937620
# 17396            5.883320  ...                387.515500
# 17397            5.883320  ...               1021.494196
# 17398            5.883320  ...                850.720305
# 17399            5.883320  ...                850.720305
#
#        dis_museum(국립 박물관과의 거리)  dis_subway(지하철역과의 거리)  brand_r(유명 아파트 브랜드순)  \
# 0                  1694.419810             849.353653                     0
# 1                  1694.419810             849.353653                     0
# 2                  1005.793754            1486.178329                     0
# 3                   277.183476            1160.598717                     0
# 4                  1361.892898             650.325555                     0
# ...                        ...                    ...                   ...
# 17395              1599.874750             874.719438                     0
# 17396              1371.750902             944.717800                     0
# 17397               913.206745             812.764336                     0
# 17398              1460.127066             717.729425                     0
# 17399              1460.127066             717.729425                     0
#
#        n_home(세대수)  n_dong(동수)  Yongpae(용적률)  Gunpae(건폐율)  Highest(최고층)  \
# 0               52           1         536.0    58.000000            13
# 1               52           1         536.0    58.000000            13
# 2             5040         124          72.0    15.000000             5
# 3             5040         124          72.0    15.000000             5
# 4             5040         124          72.0    15.000000             5
# ...            ...         ...           ...          ...           ...
# 17395           14           1         221.0    37.000000             7
# 17396           12           1         239.0    46.000000             6
# 17397           12           1         287.0    58.000000             7
# 17398           18           1         290.0    24.703887            10
# 17399           18           1         290.0    24.703887            10
#
#        Lowest(최저층)
# 0               12
# 1               12
# 2                5
# 3                5
# 4                5
# ...            ...
# 17395            7
# 17396            6
# 17397            6
# 17398           10
# 17399           10
#
# [17400 rows x 24 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split( df_multi.iloc[:,1:], df_multi.iloc[:,0],test_size = 0.3, random_state=0)
print("X_train.shape =", X_train.shape)
print("y_train.shape =", y_train.shape)
print("X_test.shape =", X_test.shape)
print("y_test.shape =", y_test.shape)
# Out:
# X_train.shape = (12180, 23)
# y_train.shape = (12180,)
# X_test.shape = (5220, 23)
# y_test.shape = (5220,)

# %%
# create object 
lr = LinearRegression(normalize=True)

# train
lr.fit(X_train, y_train)

# the above two statements can be combined as the next line
# lr = LinearRegression().fit(X_train, y_train)

# check coefficients and intercept
print("lr.coef_:", lr.coef_)             # w
print("lr.intercept_:", lr.intercept_)   # b
# Out:
# lr.coef_: [ 2.50524645e+02  1.05738665e+03  5.19984511e+02  2.51522083e+05
#  -1.49893254e+05  1.21715659e-01  2.11412521e+02  2.29972612e+03
#  -6.17957239e+03  5.61442236e+00 -2.93737426e+00 -8.07530759e+00
#   6.88887321e+00  6.15513925e+00  1.38865856e+00  6.98433752e-01
#   4.43228979e+02  3.02961908e+00  2.35547893e+02 -2.08968992e+01
#  -3.20646427e+02  2.92467472e+02  1.12165326e+03]
# lr.intercept_: 9065999.59722778
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(

# %%
# evaluation
print("Training set score: {:.2f}".format(lr.score(X_train, y_train)))
print("Test set score: {:.2f}".format(lr.score(X_test, y_test)))
# Out:
# Training set score: 0.77
# Test set score: 0.76
