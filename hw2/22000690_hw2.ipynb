# %% [markdown]
# HW_1 by 22000690 정이주
#
# 1. Objective : This code reads data_set_train.xlsx and show the yearly average price, quarterly average price, quarterly price graph and histogram.
#
# 2. Input
#
#   * Excel file (data_set_train.xlsx)
#
# 3. Output
#
#   * yearly average price  (exerrcise 4)
#   * quarterly average price  (exerrcise 5)
#   * quarterly price bar and line graph  (exerrcise 6)
#   * print out the results

# %%
import matplotlib.pyplot as plt # To draw bar and line graph
import numpy as np  # To use calculate fast 
import openpyxl # To read Excel file

# %%
file= openpyxl.load_workbook('data_set_train.xlsx') 
ws = file.active
data=[] 

for row in ws.iter_rows(min_row=2): # Read from the 2nd row 
    one_line=[]
    for cell in row: 
        one_line.append(cell.value) 
    data.append(one_line) # Save the values of each row in the list

arr = np.array(data)  # Saved in array type
data_set = arr[:,:9]  # data_set with 9 columns

# get needed data_set of each year by slicing data_set array also, get price on each data_set
# by using astype I can save the value in type that I want

data_set2006 = data_set[:2617,:] 
price2006 = data_set2006[:,2].astype(float) 

data_set2007 = data_set[2617:3937,:]  
price2007 = data_set2007[:,2].astype(float) 

data_set2008 = data_set[3937:5143,:]  
price2008 = data_set2008[:,2].astype(float) 

data_set2009 = data_set[5143:6346,:]
price2009 = data_set2009[:,2].astype(float)

data_set2010 = data_set[6346:7563,:]
price2010 = data_set2010[:,2].astype(float)

data_set2011 = data_set[7563:9037,:]
price2011 = data_set2011[:,2].astype(float)

data_set2012 = data_set[9037:10172,:]
price2012 = data_set2012[:,2].astype(float)

data_set2013 = data_set[10172:11497,:]
price2013 = data_set2013[:,2].astype(float)

data_set2014 = data_set[11497:12752,:]
price2014 = data_set2014[:,2].astype(float)

data_set2015 = data_set[12752:14248,:]
price2015 = data_set2015[:,2].astype(float)

data_set2016 = data_set[14248:15731,:]
price2016 = data_set2006[:,2].astype(float)

data_set2017 = data_set[15731:17400,:]
price2017 = data_set2017[:,2].astype(float)

# show the result
print('2006 avg : %.2f' %np.mean(price2006))
print('2007 avg : %.2f' %np.mean(price2007))
print('2007 avg : %.2f' %np.mean(price2008))
print('2009 avg : %.2f' %np.mean(price2009))
print('2010 avg : %.2f' %np.mean(price2010))
print('2011 avg : %.2f' %np.mean(price2011))
print('2012 avg : %.2f' %np.mean(price2012))
print('2013 avg : %.2f' %np.mean(price2013))
print('2014 avg : %.2f' %np.mean(price2014))
print('2015 avg : %.2f' %np.mean(price2015))
print('2016 avg : %.2f' %np.mean(price2016))
print('2017 avg : %.2f' %np.mean(price2017))
# Out:
# 2006 avg : 67076.58
# 2007 avg : 58405.72
# 2007 avg : 66136.67
# 2009 avg : 83060.50
# 2010 avg : 77282.03
# 2011 avg : 76748.97
# 2012 avg : 72714.52
# 2013 avg : 78839.02
# 2014 avg : 84002.70
# 2015 avg : 87213.44
# 2016 avg : 67076.58
# 2017 avg : 114656.79

# %%
# get needed data_set of each quarterly year by slicing data_set array also, can get price on each quarter price to calculate the average price
# by using astype I can save the value in type that I want

data_set2006Q1 = data_set[:703,:]
price2006Q1 = data_set2006Q1[:,2].astype(float)

data_set2006Q2 = data_set[703:1265,:]
price2006Q2 = data_set2006Q2[:,2].astype(float)

data_set2006Q3 = data_set[1265:1947,:]
price2006Q3 = data_set2006Q3[:,2].astype(float)

data_set2006Q4 = data_set[1947:2617,:]
price2006Q4 = data_set2006Q4[:,2].astype(float)

data_set2007Q1 = data_set[2617:2887,:]
price2007Q1 = data_set2007Q1[:,2].astype(float)

data_set2007Q2 = data_set[2887:3236,:]
price2007Q2 = data_set2007Q2[:,2].astype(float)

data_set2007Q3 = data_set[3236:3551,:]
price2007Q3 = data_set2007Q3[:,2].astype(float)

data_set2007Q4 = data_set[3551:3937,:]
price2007Q4 = data_set2007Q4[:,2].astype(float)

data_set2008Q1 = data_set[3937:4322,:]
price2008Q1 = data_set2008Q1[:,2].astype(float)

data_set2008Q2 = data_set[4322:4738,:]
price2008Q2 = data_set2008Q2[:,2].astype(float)

data_set2008Q3 = data_set[4738:4957,:]
price2008Q3 = data_set2008Q3[:,2].astype(float)

data_set2008Q4 = data_set[4957:5143,:]
price2008Q4 = data_set2008Q4[:,2].astype(float)

data_set2009Q1 = data_set[5143:5468,:]
price2009Q1 = data_set2009Q1[:,2].astype(float)

data_set2009Q2 = data_set[5468:5771,:]
price2009Q2 = data_set2009Q2[:,2].astype(float)

data_set2009Q3 = data_set[5771:6066,:]
price2009Q3 = data_set2009Q3[:,2].astype(float)

data_set2009Q4 = data_set[6066:6346,:]
price2009Q4 = data_set2009Q4[:,2].astype(float)

data_set2010Q1 = data_set[6346:6699,:]
price2010Q1 = data_set2010Q1[:,2].astype(float)

data_set2010Q2 = data_set[6699:6940,:]
price2010Q2 = data_set2010Q2[:,2].astype(float)

data_set2010Q3 = data_set[6940:7250,:]
price2010Q3 = data_set2010Q3[:,2].astype(float)

data_set2010Q4 = data_set[7250:7563,:]
price2010Q4 = data_set2010Q4[:,2].astype(float)

data_set2011Q1 = data_set[7563:7920,:]
price2011Q1 = data_set2011Q1[:,2].astype(float)

data_set2011Q2 = data_set[7920:8273,:]
price2011Q2 = data_set2011Q2[:,2].astype(float)

data_set2011Q3 = data_set[8273:8670,:]
price2011Q3 = data_set2011Q3[:,2].astype(float)

data_set2011Q4 = data_set[8670:9037,:]
price2011Q4 = data_set2011Q4[:,2].astype(float)

data_set2012Q1 = data_set[9037:9275,:]
price2012Q1 = data_set2012Q1[:,2].astype(float)

data_set2012Q2 = data_set[9275:9552,:]
price2012Q2 = data_set2012Q2[:,2].astype(float)

data_set2012Q3 = data_set[9552:9756,:]
price2012Q3 = data_set2012Q3[:,2].astype(float)

data_set2012Q4 = data_set[9756:10172,:]
price2012Q4 = data_set2012Q4[:,2].astype(float)

data_set2013Q1 = data_set[10172:10497,:]
price2013Q1 = data_set2013Q1[:,2].astype(float)

data_set2013Q2 = data_set[10497:10831,:]
price2013Q2 = data_set2013Q2[:,2].astype(float)

data_set2013Q3 = data_set[10831:11174,:]
price2013Q3 = data_set2013Q3[:,2].astype(float)

data_set2013Q4 = data_set[11174:11497,:]
price2013Q4 = data_set2013Q4[:,2].astype(float)

data_set2014Q1 = data_set[11497:11814,:]
price2014Q1 = data_set2014Q1[:,2].astype(float)

data_set2014Q2 = data_set[11814:12112,:]
price2014Q2 = data_set2014Q2[:,2].astype(float)

data_set2014Q3 = data_set[12112:12416,:]
price2014Q3 = data_set2014Q3[:,2].astype(float)

data_set2014Q4 = data_set[12416:12752,:]
price2014Q4 = data_set2014Q4[:,2].astype(float)

data_set2015Q1 = data_set[12752:13122,:]
price2015Q1 = data_set2015Q1[:,2].astype(float)

data_set2015Q2 = data_set[13122:13527,:]
price2015Q2 = data_set2015Q2[:,2].astype(float)

data_set2015Q3 = data_set[13527:13900,:]
price2015Q3 = data_set2015Q3[:,2].astype(float)

data_set2015Q4 = data_set[13900:14248,:]
price2015Q4 = data_set2015Q4[:,2].astype(float)

data_set2016Q1 = data_set[14248:14637,:]
price2016Q1 = data_set2016Q1[:,2].astype(float)

data_set2016Q2 = data_set[14637:15006,:]
price2016Q2 = data_set2016Q2[:,2].astype(float)

data_set2016Q3 = data_set[15006:15425,:]
price2016Q3 = data_set2016Q3[:,2].astype(float)

data_set2016Q4 = data_set[15425:15731,:]
price2016Q4 = data_set2016Q4[:,2].astype(float)

data_set2017Q1 = data_set[15731:16511,:]
price2017Q1 = data_set2017Q1[:,2].astype(float)

data_set2017Q2 = data_set[16511:17048,:]
price2017Q2 = data_set2017Q2[:,2].astype(float)

data_set2017Q3 = data_set[17048:17400,:]
price2017Q3 = data_set2017Q3[:,2].astype(float)

# show the result
print('2006Q1 avg : %.2f   2006Q2 avg : %.2f   2006Q3 avg : %.2f   2006Q4 avg : %.2f' %(np.mean(price2006Q1), np.mean(price2006Q2), np.mean(price2006Q3), np.mean(price2006Q4)))
print('2007Q1 avg : %.2f   2007Q2 avg : %.2f   2007Q3 avg : %.2f   2007Q4 avg : %.2f' %(np.mean(price2007Q1), np.mean(price2007Q2), np.mean(price2007Q3), np.mean(price2007Q4)))
print('2008Q1 avg : %.2f   2008Q2 avg : %.2f   2008Q3 avg : %.2f   2008Q4 avg : %.2f' %(np.mean(price2008Q1), np.mean(price2008Q2), np.mean(price2008Q3), np.mean(price2008Q4)))
print('2009Q1 avg : %.2f   2009Q2 avg : %.2f   2009Q3 avg : %.2f   2009Q4 avg : %.2f' %(np.mean(price2009Q1), np.mean(price2009Q2), np.mean(price2009Q3), np.mean(price2009Q4)))
print('2010Q1 avg : %.2f   2010Q2 avg : %.2f   2010Q3 avg : %.2f   2010Q4 avg : %.2f' %(np.mean(price2010Q1), np.mean(price2010Q2), np.mean(price2010Q3), np.mean(price2010Q4)))
print('2011Q1 avg : %.2f   2011Q2 avg : %.2f   2011Q3 avg : %.2f   2011Q4 avg : %.2f' %(np.mean(price2011Q1), np.mean(price2011Q2), np.mean(price2011Q3), np.mean(price2011Q4)))
print('2012Q1 avg : %.2f   2012Q2 avg : %.2f   2012Q3 avg : %.2f   2012Q4 avg : %.2f' %(np.mean(price2012Q1), np.mean(price2012Q2), np.mean(price2012Q3), np.mean(price2012Q4)))
print('2013Q1 avg : %.2f   2013Q2 avg : %.2f   2013Q3 avg : %.2f   2013Q4 avg : %.2f' %(np.mean(price2013Q1), np.mean(price2013Q2), np.mean(price2013Q3), np.mean(price2013Q4)))
print('2014Q1 avg : %.2f   2014Q2 avg : %.2f   2014Q3 avg : %.2f   2014Q4 avg : %.2f' %(np.mean(price2014Q1), np.mean(price2014Q2), np.mean(price2014Q3), np.mean(price2014Q4)))
print('2015Q1 avg : %.2f   2015Q2 avg : %.2f   2015Q3 avg : %.2f   2015Q4 avg : %.2f' %(np.mean(price2015Q1), np.mean(price2015Q2), np.mean(price2015Q3), np.mean(price2015Q4)))
print('2016Q1 avg : %.2f   2016Q2 avg : %.2f   2016Q3 avg : %.2f   2016Q4 avg : %.2f' %(np.mean(price2016Q1), np.mean(price2016Q2), np.mean(price2016Q3), np.mean(price2016Q4)))
print('2017Q1 avg : %.2f   2017Q2 avg : %.2f   2017Q3 avg : %.2f' %(np.mean(price2017Q1), np.mean(price2017Q2), np.mean(price2017Q3)))
# Out:
# 2006Q1 avg : 65661.17   2006Q2 avg : 59592.49   2006Q3 avg : 62410.72   2006Q4 avg : 79588.83
# 2007Q1 avg : 47336.40   2007Q2 avg : 65344.61   2007Q3 avg : 58634.69   2007Q4 avg : 59687.89
# 2008Q1 avg : 63515.58   2008Q2 avg : 62458.85   2008Q3 avg : 72233.96   2008Q4 avg : 72608.62
# 2009Q1 avg : 85574.77   2009Q2 avg : 84314.42   2009Q3 avg : 83246.47   2009Q4 avg : 78589.30
# 2010Q1 avg : 80386.73   2010Q2 avg : 71885.82   2010Q3 avg : 72697.58   2010Q4 avg : 82475.98
# 2011Q1 avg : 77359.50   2011Q2 avg : 68071.24   2011Q3 avg : 78499.77   2011Q4 avg : 82607.86
# 2012Q1 avg : 73633.61   2012Q2 avg : 73102.35   2012Q3 avg : 78050.49   2012Q4 avg : 69313.77
# 2013Q1 avg : 77980.51   2013Q2 avg : 76391.85   2013Q3 avg : 76638.47   2013Q4 avg : 84570.14
# 2014Q1 avg : 84038.77   2014Q2 avg : 81931.40   2014Q3 avg : 79218.36   2014Q4 avg : 90134.39
# 2015Q1 avg : 76180.14   2015Q2 avg : 81677.28   2015Q3 avg : 98509.43   2015Q4 avg : 93279.71
# ...

# %%
x_data = [] # x-axis
y_data = [] # y-axis

# append the value to be written on the x-axis
x_data.append('2006Q1')
x_data.append('2006Q2')
x_data.append('2006Q3')
x_data.append('2006Q4')

x_data.append('2007Q1')
x_data.append('2007Q2')
x_data.append('2007Q3')
x_data.append('2007Q4')

x_data.append('2008Q1')
x_data.append('2008Q2')
x_data.append('2008Q3')
x_data.append('2008Q4')

x_data.append('2009Q1')
x_data.append('2009Q2')
x_data.append('2009Q3')
x_data.append('2009Q4')

x_data.append('2010Q1')
x_data.append('2010Q2')
x_data.append('2010Q3')
x_data.append('2010Q4')

x_data.append('2011Q1')
x_data.append('2011Q2')
x_data.append('2011Q3')
x_data.append('2011Q4')

x_data.append('2012Q1')
x_data.append('2012Q2')
x_data.append('2012Q3')
x_data.append('2012Q4')

x_data.append('2013Q1')
x_data.append('2013Q2')
x_data.append('2013Q3')
x_data.append('2013Q4')

x_data.append('2014Q1')
x_data.append('2014Q2')
x_data.append('2014Q3')
x_data.append('2014Q4')

x_data.append('2015Q1')
x_data.append('2015Q2')
x_data.append('2015Q3')
x_data.append('2015Q4')

x_data.append('2016Q1')
x_data.append('2016Q2')
x_data.append('2016Q3')
x_data.append('2016Q4')

x_data.append('2017Q1')
x_data.append('2017Q2')
x_data.append('2017Q3')

# append the value to be written on the y-axis
# The length of the quarterly data_set for each year is the cont of quarterly trading for each year, 
# so if I can get the length of the quarterly data_set for each year, 
# the count of quarterly trading for each year can be calculated.
# This is for the bar graph
y_data.append(len(data_set2006Q1))
y_data.append(len(data_set2006Q2))
y_data.append(len(data_set2006Q3))
y_data.append(len(data_set2006Q4))

y_data.append(len(data_set2007Q1))
y_data.append(len(data_set2007Q2))
y_data.append(len(data_set2007Q3))
y_data.append(len(data_set2007Q4))

y_data.append(len(data_set2008Q1))
y_data.append(len(data_set2008Q2))
y_data.append(len(data_set2008Q3))
y_data.append(len(data_set2008Q4))

y_data.append(len(data_set2009Q1))
y_data.append(len(data_set2009Q2))
y_data.append(len(data_set2009Q3))
y_data.append(len(data_set2009Q4))

y_data.append(len(data_set2010Q1))
y_data.append(len(data_set2010Q2))
y_data.append(len(data_set2010Q3))
y_data.append(len(data_set2010Q4))

y_data.append(len(data_set2011Q1))
y_data.append(len(data_set2011Q2))
y_data.append(len(data_set2011Q3))
y_data.append(len(data_set2011Q4))

y_data.append(len(data_set2012Q1))
y_data.append(len(data_set2012Q2))
y_data.append(len(data_set2012Q3))
y_data.append(len(data_set2012Q4))

y_data.append(len(data_set2013Q1))
y_data.append(len(data_set2013Q2))
y_data.append(len(data_set2013Q3))
y_data.append(len(data_set2013Q4))

y_data.append(len(data_set2014Q1))
y_data.append(len(data_set2014Q2))
y_data.append(len(data_set2014Q3))
y_data.append(len(data_set2014Q4))

y_data.append(len(data_set2015Q1))
y_data.append(len(data_set2015Q2))
y_data.append(len(data_set2015Q3))
y_data.append(len(data_set2015Q4))

y_data.append(len(data_set2016Q1))
y_data.append(len(data_set2016Q2))
y_data.append(len(data_set2016Q3))
y_data.append(len(data_set2016Q4))

y_data.append(len(data_set2017Q1))
y_data.append(len(data_set2017Q2))
y_data.append(len(data_set2017Q3))

# This is for the line graph.
# Since I need to draw a quarterly average price graph, store the average price in the list.
# Round() can be rounded to represent the decimal point in two digits.
y_avg = []

y_avg.append(round(np.mean(price2006Q1),2))
y_avg.append(round(np.mean(price2006Q2),2))
y_avg.append(round(np.mean(price2006Q3),2))
y_avg.append(round(np.mean(price2006Q4),2))

y_avg.append(round(np.mean(price2007Q1),2))
y_avg.append(round(np.mean(price2007Q2),2))
y_avg.append(round(np.mean(price2007Q3),2))
y_avg.append(round(np.mean(price2007Q4),2))

y_avg.append(round(np.mean(price2008Q1),2))
y_avg.append(round(np.mean(price2008Q2),2))
y_avg.append(round(np.mean(price2008Q3),2))
y_avg.append(round(np.mean(price2008Q4),2))

y_avg.append(round(np.mean(price2009Q1),2))
y_avg.append(round(np.mean(price2009Q2),2))
y_avg.append(round(np.mean(price2009Q3),2))
y_avg.append(round(np.mean(price2009Q4),2))

y_avg.append(round(np.mean(price2010Q1),2))
y_avg.append(round(np.mean(price2010Q2),2))
y_avg.append(round(np.mean(price2010Q3),2))
y_avg.append(round(np.mean(price2010Q4),2))

y_avg.append(round(np.mean(price2011Q1),2))
y_avg.append(round(np.mean(price2011Q2),2))
y_avg.append(round(np.mean(price2011Q3),2))
y_avg.append(round(np.mean(price2011Q4),2))

y_avg.append(round(np.mean(price2012Q1),2))
y_avg.append(round(np.mean(price2012Q2),2))
y_avg.append(round(np.mean(price2012Q3),2))
y_avg.append(round(np.mean(price2012Q4),2))

y_avg.append(round(np.mean(price2013Q1),2))
y_avg.append(round(np.mean(price2013Q2),2))
y_avg.append(round(np.mean(price2013Q3),2))
y_avg.append(round(np.mean(price2013Q4),2))

y_avg.append(round(np.mean(price2014Q1),2))
y_avg.append(round(np.mean(price2014Q2),2))
y_avg.append(round(np.mean(price2014Q3),2))
y_avg.append(round(np.mean(price2014Q4),2))

y_avg.append(round(np.mean(price2015Q1),2))
y_avg.append(round(np.mean(price2015Q2),2))
y_avg.append(round(np.mean(price2015Q3),2))
y_avg.append(round(np.mean(price2015Q4),2))

y_avg.append(round(np.mean(price2016Q1),2))
y_avg.append(round(np.mean(price2016Q2),2))
y_avg.append(round(np.mean(price2016Q3),2))
y_avg.append(round(np.mean(price2016Q4),2))

y_avg.append(round(np.mean(price2017Q1),2))
y_avg.append(round(np.mean(price2017Q2),2))
y_avg.append(round(np.mean(price2017Q3),2))

# %%
plt.figure(figsize=(50,10)) # set the bar graph size
plt.title('Count of trading in quarters') # show the bar graph title
xtick_pos = list(range(len(x_data))) 
plt.xticks(xtick_pos, x_data) # use to mark the scale on the x-axis of a graph
plt.bar(xtick_pos, y_data, width = 0.5, align = 'center', color = 'green') # draw a bar graph

plt.show()  # show bar graph

plt.figure(figsize=(50,10)) # set the line graph size
plt.title('Quarterly average price') # show the line graph title
plt.xticks(xtick_pos, x_data) # use to mark the scale on the x-axis of a graph
plt.plot(xtick_pos, y_avg, color = 'red') # draw a line graph
plt.scatter(xtick_pos, y_avg, color = 'r') # Mark a value with a dot
plt.show()  # show line graph
